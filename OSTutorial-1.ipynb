# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_ex
# ...

# %%
print(os.getcwd())
# Out:
# c:\Users\absep\Desktop\Week 3\exerPythOsTutorial

# %%
os.chdir('/Users/absep/Desktop/')

# %%
print(os.getcwd())
# Out:
# c:\Users\absep\Desktop

# %%
os.mkdir('OS-Demo-2')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17028/3856293951.py in <module>
# ----> 1 os.mkdir('OS-Demo-2')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'OS-Demo-2'

# %%
os.makedirs('OS-Demo-2/Sub-Dir-1')

# %%
os.rmdir('OS-Demo-2/Sub-Dir-1')

# %%
os.makedirs('test.tex/Sub-dir-1')

# %%
os.removedirs('test.tex/Sub-dir-1')

# %%
os.rename('test', 'demo')

# %%
from datetime import datetime

# %%
mod_time = os.stat('demo').st_mtime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2021-09-01 13:21:30.071518

# %%
print(os.stat('demo'))
# Out:
# os.stat_result(st_mode=16895, st_ino=23362423067017154, st_dev=1376688436, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1631144135, st_mtime=1630524090, st_ctime=1630524008)

# %%
print(os.listdir())
# Out:
# ['Allen (Maddi) - Chrome.lnk', 'Allen - Chrome.lnk', 'demo', 'desktop.ini', 'Hulu.lnk', 'myProject', 'NuSkin Outlook.html', 'OS-Demo-2', 'OS-test', 'PicturePerfectPropertiesEbookAndBonuses', 'PicturePerfectPropertiesEbookAndBonuses.zip', 'Primary Arms - SalesOrd70495800.pdf', 'Property Photography Mastery For Estate Agents Ebook by FocalAgent.pdf', 'Rider', 'The Gospel Light of Truth and Love.pdf', 'Visual Studio Code.lnk', 'Waiver-Boise-Art-Glass.pdf', 'Week 3', 'Week2', 'Window_driver', 'Zoom.lnk']

# %%
for dirpath, dirnames, filenames in os.walk('/Users/absep/Desktop/'):
    print('Current Path:', dirpath)
    print('Directories:', dirnames)
    print('Files:', filenames)
    print()
# Out:
# Current Path: /Users/absep/Desktop/
# Directories: ['demo', 'myProject', 'OS-Demo-2', 'OS-test', 'PicturePerfectPropertiesEbookAndBonuses', 'Rider', 'Week 3', 'Week2', 'Window_driver']
# Files: ['Allen (Maddi) - Chrome.lnk', 'Allen - Chrome.lnk', 'desktop.ini', 'Hulu.lnk', 'NuSkin Outlook.html', 'PicturePerfectPropertiesEbookAndBonuses.zip', 'Primary Arms - SalesOrd70495800.pdf', 'Property Photography Mastery For Estate Agents Ebook by FocalAgent.pdf', 'The Gospel Light of Truth and Love.pdf', 'Visual Studio Code.lnk', 'Waiver-Boise-Art-Glass.pdf', 'Zoom.lnk']
#
# Current Path: /Users/absep/Desktop/demo
# Directories: ['.git', 'exerPythCheckInstal']
# Files: []
#
# Current Path: /Users/absep/Desktop/demo\.git
# Directories: ['hooks', 'info', 'objects', 'refs']
# Files: ['config', 'description', 'HEAD']
#
# Current Path: /Users/absep/Desktop/demo\.git\hooks
# Directories: []
# ...

# %%
print(os.environ.get('HOME'))
# Out:
# None

# %%
file_path = os.path.join(os.environ.get('HOME'), 'demo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17028/1678187595.py in <module>
# ----> 1 file_path = os.path.join(os.environ.get('HOME'), 'demo')
#
# ~\.conda\envs\Python Program Env\lib\ntpath.py in join(path, *paths)
#      76 # Join two (or more) paths.
#      77 def join(path, *paths):
# ---> 78     path = os.fspath(path)
#      79     if isinstance(path, bytes):
#      80         sep = b'\\'
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
os.path.basename('test.txt')
# Out:
# 'test.txt'

# %%
os.path.dirname('test.txt')
# Out:
# ''

# %%
os.path.split('test.txt')
# Out:
# ('', 'test.txt')

# %%
os.path.exists('test.txt')
# Out:
# False

# %%
os.path.isdir('test.txt')
# Out:
# False

# %%
os.path.isfile('test.txt')
# Out:
# False

# %%
os.path.splitext('test.txt')
# Out:
# ('test', '.txt')

# %%
# https://realpython.com/python-comments-guide/

# %%
# https://python101.pythonlibrary.org/chapter16_os.html
